# %%
import sys
import os
import pandas as pd


module_path =os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

if module_path not in sys.path:
    sys.path.append(module_path+"\\models")

# %%
from loadDvc import dvcData

# %%
dvcInstance=dvcData()

# %%
data=dvcInstance.getData('data/AdSmartABdata.csv','https://github.com/Blvisse/ABtesting','5fee50074d92ecda5692c4ad2f60cc3827bd6a19')

# %%
data['platform_os'].value_counts()
# Out:
# 6    7648
# 5     428
# 7       1
# Name: platform_os, dtype: int64

# %%
data
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make  platform_os                browser  yes  no
# ...

# %%
platform7=data[data['platform_os']==7]
platform6=data[data['platform_os']==6]
platform5=data[data['platform_os']==5]

# %%
platform6
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make  platform_os                browser  yes  no
# ...

# %%
platform5
# Out:
#                                 auction_id experiment        date  hour  \
# 10    004c8a83-1c0f-4a4a-ba9e-bc89e8c0c0c1    control  2020-07-10    13
# 25    00d22463-2d1f-44de-8d67-11d6c6b96a00    exposed  2020-07-03     1
# 26    00e4f247-b54b-4f95-a000-ec4645d5a692    control  2020-07-03    15
# 51    01b04c3a-8107-4b53-8532-122ff003f900    control  2020-07-04     4
# 73    0270f4d1-654e-42e9-afec-76963504ef45    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8009  fd485e19-fb47-4223-8dc2-7bae945c08fa    control  2020-07-08    19
# 8018  fd93b48c-d634-4994-9643-f0f6282ebca7    control  2020-07-04    16
# 8034  fe6ae1c4-ff79-47c1-9cb5-a8d5e5402745    control  2020-07-03    15
# 8052  ff7534ce-cf85-48fa-b22f-a8797107f15c    exposed  2020-07-09     6
# 8057  ff91d4f2-d28f-4a66-9e5c-bf1c96e32a4c    control  2020-07-04    17
#
#      device_make  platform_os                     browser  yes  no
# ...

# %%
platform7
# Out:
#                                 auction_id experiment        date  hour  \
# 2332  4c4332e4-25ce-483b-a565-76a76a802ca6    exposed  2020-07-03    13
#
#      device_make  platform_os      browser  yes  no
# 2332   Lumia 950            7  Edge Mobile    0   0

# %%
platform6.to_csv('../data/AdSmartABdata.csv',index=False)

# %%
platform7.to_csv('../data/AdSmartABdata.csv',index=False)

# %%
platform5.to_csv('../data/AdSmartABdata.csv',index=False)

# %%
data['browser'].value_counts()
# Out:
# Chrome Mobile                 4554
# Chrome Mobile WebView         1489
# Samsung Internet               824
# Facebook                       764
# Mobile Safari                  337
# Chrome Mobile iOS               51
# Mobile Safari UI/WKWebView      44
# Chrome                           3
# Pinterest                        3
# Opera Mobile                     3
# Firefox Mobile                   1
# Opera Mini                       1
# Puffin                           1
# Edge Mobile                      1
# Android                          1
# Name: browser, dtype: int64

# %%
ChromeMobile=data[data['browser']=='Chrome Mobile']
ChromeMobileWeb=data[data['browser']=='Chrome Mobile WebView']
Samsung=data[data['browser']=='Samsung Internet']
Facebook=data[data['browser']=='Facebook']
MobileSafari=data[data['browser']=='Mobile Safari']
ChromeiOS=data[data['browser']=='Chrome Mobile iOS']
SafariUI=data[data['browser']=='Mobile Safari UI/WKWebView']

# %%
dataBrowser=data.drop(labels=['platform_os'],axis=1)

# %%
dataPlatform=data.drop(labels=['browser'],axis=1)

# %%
dataBrowser
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make                browser  yes  no
# ...

# %%
dataBrowser.to_csv('../data/AdSmartABdata.csv',index=False)

# %%
dataPlatform.to_csv('../data/AdSmartABdata.csv',index=False)

# %%
import dvc.api

version='v4'
data6=dvc.api.get_url(path='data/AdSmartABdata.csv',repo='https://github.com/Blvisse/ABtesting',rev='5fee50074d92ecda5692c4ad2f60cc3827bd6a19')

# %%
data6
# Out:
# '..\\..\\..\\..\\..\\..\\..\\tmp\\dvc-storage\\1a\\e19300fae64a8d41f40122d8f68a53'

# %%
data6=pd.read_csv(data6)

# %%
data6
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make  platform_os                browser  yes  no
# ...

# %%
data=data[data['platform_os']==5]

# %%
data.to_csv('../data/AdSmartABdata.csv',index=False)

# %%
data=data[data['browser']=='Chrome Mobile']
data
# Out:
# Empty DataFrame
# Columns: [auction_id, experiment, date, hour, device_make, platform_os, browser, yes, no]
# Index: []

# %%
data
# Out:
# Empty DataFrame
# Columns: [auction_id, experiment, date, hour, device_make, platform_os, browser, yes, no]
# Index: []

# %%
import dvc.api

path=
