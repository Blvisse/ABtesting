# %%
import sys
import os


module_path =os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\scripts")

if module_path not in sys.path:
    sys.path.append(module_path+"\\models")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss

# %%
from loadDvc import dvcData

# %%
instance=dvcData('data/AdSmartABdata.csv','v1','https://github.com/Blvisse/ABtesting/tree/a')

# %%
data=instance.getData()

# %%
data

# %%
import dvc.api 
data=dvc.api.get_url(path='data/AdSmartABdata.csv',repo='https://github.com/Blvisse/ABtesting')

# %%
data=pd.read_csv(data)

# %%
data
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make  platform_os                browser  yes  no
# ...

# %%
data_url['browser'].value_counts()
# Out:
# Chrome Mobile                 4554
# Chrome Mobile WebView         1489
# Samsung Internet               824
# Facebook                       764
# Mobile Safari                  337
# Chrome Mobile iOS               51
# Mobile Safari UI/WKWebView      44
# Opera Mobile                     3
# Pinterest                        3
# Chrome                           3
# Edge Mobile                      1
# Opera Mini                       1
# Android                          1
# Firefox Mobile                   1
# Puffin                           1
# Name: browser, dtype: int64

# %%
data_url['platform_os'].value_counts()
# Out:
# 6    7648
# 5     428
# 7       1
# Name: platform_os, dtype: int64

# %%
data=data_url[data_url['platform_os']==6]

# %%
data
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make  platform_os                browser  yes  no
# ...

# %%
data.to_csv('')
